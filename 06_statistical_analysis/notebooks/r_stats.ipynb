# %%
#!/usr/bin/env Rscript

# Load libraries
require(ggplot2)
require(reshape2)

# Step 1: Read the CSV file
bids <- "/om2/user/mabdel03/files/Ravi_ISO_MRI/reformatted/"
read_csv <- file.path(bids, "code", "slm_data2.csv")
data <- read.csv(read_csv)
colnames <- names(data)

# Extract subsets with QC
fmri_data <- subset(data, fmri_qc == 1)
dwi_data <- subset(data, dwi_qc == 1)
anat_data <- subset(data, anat_qc == 1)

# Set working directory
setwd(file.path(bids, "code", "model_outputs"))
# Out:
# Loading required package: ggplot2
#
# Loading required package: reshape2

# %%
run_ols_model <- function(dataframe, main_predictor, main_dependent, covariates_numeric = NULL, covariates_factor = NULL) {
  # Selecting relevant columns from the dataframe
  data_subset <- dataframe[, c(main_predictor, main_dependent, covariates_numeric, covariates_factor)]
  
  # Remove rows with missing values
  data_subset <- na.omit(data_subset)
  
  # Z-scoring main predictor and dependent variable along with numeric covariates if they are not empty
  numeric_cols <- c(main_predictor, main_dependent, covariates_numeric)
  if (!is.null(numeric_cols)) {
    data_subset[numeric_cols] <- scale(data_subset[numeric_cols])
  }
  
  # Converting factor variables to factor type
  if (!is.null(covariates_factor)) {
    for (factor_var in covariates_factor) {
      data_subset[[factor_var]] <- factor(data_subset[[factor_var]])
    }
  }
  
  # Constructing formula strings
  if (is.null(covariates_numeric) && is.null(covariates_factor)) {
    formula_string_full <- paste(main_dependent, "~", main_predictor)
    formula_string_reduced <- formula_string_full
  } else {
    formula_terms <- c(main_predictor, covariates_numeric, covariates_factor)
    formula_string_full <- paste(main_dependent, "~", paste(formula_terms, collapse = " + "))
    formula_string_reduced <- paste(main_dependent, "~", paste(setdiff(formula_terms, main_predictor), collapse = " + "))
  }
  
  # Running the full OLS model
  ols_model_full <- lm(formula_string_full, data = data_subset)
  
  # Running the reduced OLS model
  ols_model_reduced <- lm(formula_string_reduced, data = data_subset)
  
  # Calculating residuals from the full model
  #residuals_full <- residuals(ols_model_full)
  
  # Plotting main predictor vs residuals
  #plot(data_subset[[main_predictor]], residuals_full, xlab = main_predictor, ylab = "Residuals (Actual - Predicted)", main = "Main Predictor vs Residuals")
  
  # Adding best fit line
  #abline(lm(residuals_full ~ data_subset[[main_predictor]]), col = "red")
  
  # Adding confidence intervals around the best fit line
  #lines(predict(lm(residuals_full ~ data_subset[[main_predictor]]), interval = "confidence"), col = "blue", lty = 2)
  
  # Calculating adjusted R-squared for the full model
  adj_rsq_full <- summary(ols_model_full)$adj.r.squared
  
  # Calculating adjusted R-squared for the reduced model
  adj_rsq_reduced <- summary(ols_model_reduced)$adj.r.squared
  
  # Calculating change in adjusted R-squared
  delta_adj_rsq <- adj_rsq_full - adj_rsq_reduced
  
  # Printing formula for the full model
  cat("Formula (Full Model):", formula_string_full, "\n\n")
  cat("Formula (Reduced Model):", formula_string_reduced, "\n\n")
  
  # Printing model summary for the full model
  cat("Model Summary (Full Model):\n")
  print(summary(ols_model_full))
  
  # Printing change in adjusted R-squared
  cat("\nChange in Adjusted R-squared (Full vs Reduced Model):", delta_adj_rsq, "\n\n")
  
  # Returning the OLS model object for the full model
  return(list(model = ols_model_full, delta_adj_rsq = delta_adj_rsq))
}

# %%
string_to_match <- "dwi.*white.*"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
columns_match
# Out:
# [1] "dwi_white_matter_average_ad"     "dwi_white_matter_average_dti_fa"
# [3] "dwi_white_matter_average_md"     "dwi_white_matter_average_qa"
# [5] "dwi_white_matter_average_rd"

# %%
# Run a model
data_model <- dwi_data
string_to_match <- "dwi.*AAL.*Frontal.*_dti_fa"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit", "dwi_white_matter_average_dti_fa")
    covariates_factor <- c("pheno_msex")
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor)
    }
string_to_match <- "regionsurfacestats.*AAL.*Frontal.*Vol"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
# Out:
# Formula (Full Model): dwi_AAL_Frontal_Sup_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Sup_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.2942 -0.5122  0.0060  0.4809  4.4834
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.030996   0.037232   0.833   0.4055
# pheno_social_isolation           0.004964   0.033209   0.149   0.8812
# pheno_age_at_visit              -0.056332   0.034328  -1.641   0.1014
# dwi_white_matter_average_dti_fa  0.626195   0.034150  18.337   <2e-16 ***
# pheno_msex1                     -0.130044   0.076449  -1.701   0.0895 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.767 on 553 degrees of freedom
# Multiple R-squared:  0.416,	Adjusted R-squared:  0.4118
# F-statistic: 98.48 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.00103806
#
# Formula (Full Model): dwi_AAL_Frontal_Sup_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Sup_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0658 -0.5544 -0.0087  0.5220  5.0541
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.05831    0.03747   1.556  0.12025
# pheno_social_isolation          -0.03081    0.03342  -0.922  0.35695
# pheno_age_at_visit              -0.09340    0.03455  -2.704  0.00707 **
# dwi_white_matter_average_dti_fa  0.59410    0.03437  17.287  < 2e-16 ***
# pheno_msex1                     -0.24462    0.07693  -3.180  0.00156 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7718 on 553 degrees of freedom
# Multiple R-squared:  0.4086,	Adjusted R-squared:  0.4043
# F-statistic:  95.5 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.000161285
#
# Formula (Full Model): dwi_AAL_Frontal_Sup_Orb_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Sup_Orb_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.13441 -0.48960 -0.06225  0.46161  2.75770
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -0.06062    0.03684  -1.646 0.100426
# pheno_social_isolation          -0.04862    0.03286  -1.480 0.139543
# pheno_age_at_visit              -0.05919    0.03396  -1.743 0.081947 .
# dwi_white_matter_average_dti_fa  0.61402    0.03379  18.173  < 2e-16 ***
# pheno_msex1                      0.25432    0.07564   3.362 0.000826 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7588 on 553 degrees of freedom
# Multiple R-squared:  0.4283,	Adjusted R-squared:  0.4242
# F-statistic: 103.6 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001236146
#
# Formula (Full Model): dwi_AAL_Frontal_Sup_Orb_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Sup_Orb_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1910 -0.5593 -0.0705  0.4375  3.7838
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -0.02387    0.03881  -0.615  0.53882
# pheno_social_isolation          -0.05454    0.03461  -1.576  0.11567
# pheno_age_at_visit              -0.11095    0.03578  -3.101  0.00203 **
# dwi_white_matter_average_dti_fa  0.54901    0.03560  15.424  < 2e-16 ***
# pheno_msex1                      0.10013    0.07969   1.257  0.20943
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7994 on 553 degrees of freedom
# Multiple R-squared:  0.3655,	Adjusted R-squared:  0.3609
# F-statistic: 79.64 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001710494
#
# Formula (Full Model): dwi_AAL_Frontal_Mid_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Mid_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.5768 -0.4625  0.0061  0.4564  3.5886
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.04977    0.03416   1.457  0.14565
# pheno_social_isolation          -0.03637    0.03047  -1.194  0.23301
# pheno_age_at_visit              -0.14770    0.03149  -4.690 3.45e-06 ***
# dwi_white_matter_average_dti_fa  0.64539    0.03133  20.600  < 2e-16 ***
# pheno_msex1                     -0.20881    0.07013  -2.977  0.00304 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7036 on 553 degrees of freedom
# Multiple R-squared:  0.5085,	Adjusted R-squared:  0.5049
# F-statistic:   143 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0003802541
#
# Formula (Full Model): dwi_AAL_Frontal_Mid_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Mid_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.32191 -0.51983 -0.00578  0.51160  2.97015
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.06194    0.03645   1.699 0.089854 .
# pheno_social_isolation          -0.03710    0.03251  -1.141 0.254274
# pheno_age_at_visit              -0.16294    0.03361  -4.848 1.62e-06 ***
# dwi_white_matter_average_dti_fa  0.58306    0.03343  17.439  < 2e-16 ***
# pheno_msex1                     -0.25985    0.07485  -3.472 0.000557 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7509 on 553 degrees of freedom
# Multiple R-squared:  0.4402,	Adjusted R-squared:  0.4362
# F-statistic: 108.7 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0003077375
#
# Formula (Full Model): dwi_AAL_Frontal_Mid_Orb_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Mid_Orb_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4366 -0.4869  0.0134  0.5053  2.9388
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.01095    0.03652   0.300   0.7645
# pheno_social_isolation          -0.06048    0.03258  -1.856   0.0639 .
# pheno_age_at_visit              -0.13621    0.03367  -4.045 5.97e-05 ***
# dwi_white_matter_average_dti_fa  0.59653    0.03350  17.807  < 2e-16 ***
# pheno_msex1                     -0.04593    0.07499  -0.612   0.5405
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7524 on 553 degrees of freedom
# Multiple R-squared:  0.438,	Adjusted R-squared:  0.434
# F-statistic: 107.8 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.00249962
#
# Formula (Full Model): dwi_AAL_Frontal_Mid_Orb_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Mid_Orb_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.94593 -0.51954 -0.06407  0.45959  2.99964
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.05368    0.03881   1.383  0.16723
# pheno_social_isolation          -0.06663    0.03462  -1.925  0.05478 .
# pheno_age_at_visit              -0.14554    0.03579  -4.067 5.45e-05 ***
# dwi_white_matter_average_dti_fa  0.52468    0.03560  14.738  < 2e-16 ***
# pheno_msex1                     -0.22521    0.07970  -2.826  0.00489 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7995 on 553 degrees of freedom
# Multiple R-squared:  0.3653,	Adjusted R-squared:  0.3607
# F-statistic: 79.58 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.003120852
#
# Formula (Full Model): dwi_AAL_Frontal_Inf_Oper_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Inf_Oper_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.13752 -0.48941 -0.00559  0.49402  2.97363
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.0260361  0.0356192   0.731    0.465
# pheno_social_isolation          -0.0008793  0.0317704  -0.028    0.978
# pheno_age_at_visit              -0.2803721  0.0328408  -8.537   <2e-16 ***
# dwi_white_matter_average_dti_fa  0.5446280  0.0326707  16.670   <2e-16 ***
# pheno_msex1                     -0.1092342  0.0731377  -1.494    0.136
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7337 on 553 degrees of freedom
# Multiple R-squared:  0.4655,	Adjusted R-squared:  0.4616
# F-statistic: 120.4 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0009710599
#
# Formula (Full Model): dwi_AAL_Frontal_Inf_Oper_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Inf_Oper_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.02146 -0.60042 -0.08147  0.51486  2.69509
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -0.001807   0.039435  -0.046    0.963
# pheno_social_isolation          -0.054751   0.035174  -1.557    0.120
# pheno_age_at_visit              -0.231729   0.036359  -6.373  3.9e-10 ***
# dwi_white_matter_average_dti_fa  0.462616   0.036171  12.790  < 2e-16 ***
# pheno_msex1                      0.007583   0.080973   0.094    0.925
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8124 on 553 degrees of freedom
# Multiple R-squared:  0.3448,	Adjusted R-squared:  0.3401
# F-statistic: 72.76 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001694964
#
# Formula (Full Model): dwi_AAL_Frontal_Inf_Tri_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Inf_Tri_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.90107 -0.44653 -0.01692  0.40170  2.94217
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.009668   0.032274   0.300    0.765
# pheno_social_isolation          -0.046623   0.028787  -1.620    0.106
# pheno_age_at_visit              -0.235215   0.029757  -7.905 1.47e-14 ***
# dwi_white_matter_average_dti_fa  0.636002   0.029603  21.485  < 2e-16 ***
# pheno_msex1                     -0.040561   0.066270  -0.612    0.541
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6648 on 553 degrees of freedom
# Multiple R-squared:  0.5612,	Adjusted R-squared:  0.558
# F-statistic: 176.8 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001294994
#
# Formula (Full Model): dwi_AAL_Frontal_Inf_Tri_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Inf_Tri_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.38041 -0.50765  0.00847  0.45727  2.65892
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.03768    0.03494   1.078    0.281
# pheno_social_isolation          -0.04578    0.03117  -1.469    0.142
# pheno_age_at_visit              -0.17556    0.03222  -5.449 7.63e-08 ***
# dwi_white_matter_average_dti_fa  0.61386    0.03205  19.153  < 2e-16 ***
# pheno_msex1                     -0.15809    0.07175  -2.203    0.028 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7198 on 553 degrees of freedom
# Multiple R-squared:  0.4856,	Adjusted R-squared:  0.4819
# F-statistic: 130.5 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001082378
#
# Formula (Full Model): dwi_AAL_Frontal_Inf_Orb_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Inf_Orb_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8337 -0.4832 -0.0250  0.3933  6.1271
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.04476    0.03805   1.176   0.2400
# pheno_social_isolation          -0.02581    0.03394  -0.760   0.4473
# pheno_age_at_visit              -0.17434    0.03508  -4.969 8.98e-07 ***
# dwi_white_matter_average_dti_fa  0.54245    0.03490  15.542  < 2e-16 ***
# pheno_msex1                     -0.18779    0.07813  -2.403   0.0166 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7838 on 553 degrees of freedom
# Multiple R-squared:   0.39,	Adjusted R-squared:  0.3856
# F-statistic: 88.39 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0004676817
#
# Formula (Full Model): dwi_AAL_Frontal_Inf_Orb_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Inf_Orb_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6383 -0.5533 -0.0420  0.4198  5.5782
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.09726    0.03874   2.511   0.0123 *
# pheno_social_isolation          -0.04331    0.03455  -1.253   0.2106
# pheno_age_at_visit              -0.18929    0.03572  -5.300 1.68e-07 ***
# dwi_white_matter_average_dti_fa  0.49122    0.03553  13.826  < 2e-16 ***
# pheno_msex1                     -0.40804    0.07954  -5.130 4.01e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.798 on 553 degrees of freedom
# Multiple R-squared:  0.3678,	Adjusted R-squared:  0.3633
# F-statistic: 80.44 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0006565582
#
# Formula (Full Model): dwi_AAL_Frontal_Sup_Medial_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Sup_Medial_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9729 -0.4855 -0.0623  0.4675  7.1938
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.05927    0.04024   1.473  0.14135
# pheno_social_isolation          -0.05525    0.03589  -1.539  0.12431
# pheno_age_at_visit              -0.10764    0.03710  -2.901  0.00387 **
# dwi_white_matter_average_dti_fa  0.50310    0.03691  13.630  < 2e-16 ***
# pheno_msex1                     -0.24868    0.08263  -3.010  0.00274 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.829 on 553 degrees of freedom
# Multiple R-squared:  0.3177,	Adjusted R-squared:  0.3128
# F-statistic: 64.38 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001698546
#
# Formula (Full Model): dwi_AAL_Frontal_Sup_Medial_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Sup_Medial_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9774 -0.5429 -0.0776  0.4948  4.0214
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                      0.0595556  0.0388718   1.532 0.126070
# pheno_social_isolation          -0.0008331  0.0346715  -0.024 0.980838
# pheno_age_at_visit              -0.1360502  0.0358397  -3.796 0.000163 ***
# dwi_white_matter_average_dti_fa  0.5420086  0.0356540  15.202  < 2e-16 ***
# pheno_msex1                     -0.2498647  0.0798164  -3.130 0.001837 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8007 on 553 degrees of freedom
# Multiple R-squared:  0.3634,	Adjusted R-squared:  0.3588
# F-statistic: 78.92 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001156723
#
# Formula (Full Model): dwi_AAL_Frontal_Med_Orb_L_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Med_Orb_L_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3969 -0.5968 -0.0724  0.5179  5.1060
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -0.01848    0.04454  -0.415   0.6784
# pheno_social_isolation          -0.05481    0.03973  -1.380   0.1682
# pheno_age_at_visit              -0.07666    0.04107  -1.867   0.0625 .
# dwi_white_matter_average_dti_fa  0.36150    0.04085   8.848   <2e-16 ***
# pheno_msex1                      0.07754    0.09146   0.848   0.3969
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9175 on 553 degrees of freedom
# Multiple R-squared:  0.1642,	Adjusted R-squared:  0.1581
# F-statistic: 27.15 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001373251
#
# Formula (Full Model): dwi_AAL_Frontal_Med_Orb_R_dti_fa ~ pheno_social_isolation + pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Formula (Reduced Model): dwi_AAL_Frontal_Med_Orb_R_dti_fa ~ pheno_age_at_visit + dwi_white_matter_average_dti_fa + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1867 -0.5542 -0.0333  0.5021  7.3046
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -0.0003731  0.0418036  -0.009    0.993
# pheno_social_isolation           0.0433823  0.0372865   1.163    0.245
# pheno_age_at_visit               0.0118402  0.0385428   0.307    0.759
# dwi_white_matter_average_dti_fa  0.5207891  0.0383431  13.582   <2e-16 ***
# pheno_msex1                      0.0015651  0.0858363   0.018    0.985
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8611 on 553 degrees of freedom
# Multiple R-squared:  0.2638,	Adjusted R-squared:  0.2584
# F-statistic: 49.53 on 4 and 553 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0004734498

# %%
# Run a model
data_model <- anat_data
#main_dependent <- "pheno_social_isolation"
#main_predictor <- "bold_AAL_Precuneus_L_alff"
#covariates_numeric <- c("pheno_age_at_visit",'bold_wholebrain_average_alff')
#covariates_factor <- c("pheno_msex")
# Find all columns with "bold_AAL_XXXXX_t1t2ratio"
string_to_match <- "regionsurfacestats.*AAL.*Frontal.*SurfArea*"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit","brainmeasures_EstimatedTotalIntraCranialVol_eTIV")
    covariates_factor <- c("pheno_msex")
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor)
    }
string_to_match <- "regionsurfacestats.*AAL.*Frontal.*Vol"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
# Out:
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Sup_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.02724 -0.49164 -0.04401  0.48192  2.31438
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.03504    0.03842  -0.912
# pheno_social_isolation                           -0.02878    0.03333  -0.864
# pheno_age_at_visit                               -0.32083    0.03367  -9.528
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.60332    0.03929  15.357
# pheno_msex1                                       0.16651    0.09552   1.743
#                                                  Pr(>|t|)
# (Intercept)                                        0.3623
# pheno_social_isolation                             0.3883
# pheno_age_at_visit                                 <2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV   <2e-16 ***
# pheno_msex1                                        0.0819 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7315 on 494 degrees of freedom
# Multiple R-squared:  0.4691,	Adjusted R-squared:  0.4648
# F-statistic: 109.1 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0002748978
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Sup_Orb_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1588 -0.4857 -0.0271  0.4524  5.7224
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.02282    0.04134  -0.552
# pheno_social_isolation                           -0.03903    0.03586  -1.089
# pheno_age_at_visit                               -0.40985    0.03622 -11.314
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.48762    0.04226  11.537
# pheno_msex1                                       0.10845    0.10276   1.055
#                                                  Pr(>|t|)
# (Intercept)                                         0.581
# pheno_social_isolation                              0.277
# pheno_age_at_visit                                 <2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV   <2e-16 ***
# pheno_msex1                                         0.292
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.787 on 494 degrees of freedom
# Multiple R-squared:  0.3856,	Adjusted R-squared:  0.3806
# F-statistic: 77.52 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0002312963
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Mid_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.96740 -0.49523  0.04094  0.45714  2.30380
#
# Coefficients:
#                                                   Estimate Std. Error t value
# (Intercept)                                      -0.042576   0.037091  -1.148
# pheno_social_isolation                           -0.007081   0.032172  -0.220
# pheno_age_at_visit                               -0.369430   0.032503 -11.366
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.602270   0.037923  15.881
# pheno_msex1                                       0.202339   0.092205   2.194
#                                                  Pr(>|t|)
# (Intercept)                                        0.2516
# pheno_social_isolation                             0.8259
# pheno_age_at_visit                                 <2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV   <2e-16 ***
# pheno_msex1                                        0.0287 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7061 on 494 degrees of freedom
# Multiple R-squared:  0.5054,	Adjusted R-squared:  0.5014
# F-statistic: 126.2 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0009585519
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Mid_Orb_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.59799 -0.50309 -0.02614  0.47964  2.17455
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.06202    0.04169  -1.488
# pheno_social_isolation                           -0.03984    0.03616  -1.102
# pheno_age_at_visit                               -0.37514    0.03653 -10.268
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.44589    0.04263  10.460
# pheno_msex1                                       0.29474    0.10364   2.844
#                                                  Pr(>|t|)
# (Intercept)                                       0.13750
# pheno_social_isolation                            0.27114
# pheno_age_at_visit                                < 2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                       0.00464 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7937 on 494 degrees of freedom
# Multiple R-squared:  0.375,	Adjusted R-squared:   0.37
# F-statistic: 74.11 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.000271991
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Inf_Oper_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7416 -0.5409 -0.0915  0.4243  3.3513
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.02862    0.04473  -0.640
# pheno_social_isolation                           -0.04472    0.03880  -1.153
# pheno_age_at_visit                               -0.20511    0.03920  -5.233
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.47916    0.04573  10.477
# pheno_msex1                                       0.13603    0.11120   1.223
#                                                  Pr(>|t|)
# (Intercept)                                         0.523
# pheno_social_isolation                              0.250
# pheno_age_at_visit                               2.47e-07 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                         0.222
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8516 on 494 degrees of freedom
# Multiple R-squared:  0.2806,	Adjusted R-squared:  0.2748
# F-statistic: 48.18 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0004814809
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Inf_Tri_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1574 -0.5650 -0.1115  0.4736  2.9562
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.05379    0.04474  -1.202
# pheno_social_isolation                            0.02690    0.03880   0.693
# pheno_age_at_visit                               -0.29079    0.03920  -7.417
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.40927    0.04574   8.948
# pheno_msex1                                       0.25562    0.11121   2.298
#                                                  Pr(>|t|)
# (Intercept)                                         0.230
# pheno_social_isolation                              0.489
# pheno_age_at_visit                               5.24e-13 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                         0.022 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8517 on 494 degrees of freedom
# Multiple R-squared:  0.2804,	Adjusted R-squared:  0.2746
# F-statistic: 48.12 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0007615031
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Inf_Orb_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.59678 -0.57931 -0.01739  0.53668  2.55069
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.08129    0.04271  -1.903
# pheno_social_isolation                           -0.01445    0.03704  -0.390
# pheno_age_at_visit                               -0.21806    0.03743  -5.826
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.46600    0.04367  10.672
# pheno_msex1                                       0.38631    0.10617   3.639
#                                                  Pr(>|t|)
# (Intercept)                                      0.057584 .
# pheno_social_isolation                           0.696717
# pheno_age_at_visit                               1.02e-08 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                      0.000303 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8131 on 494 degrees of freedom
# Multiple R-squared:  0.3442,	Adjusted R-squared:  0.3389
# F-statistic: 64.81 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001132497
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Sup_Medial_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3622 -0.4266 -0.0133  0.4225  5.9991
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.06737    0.03756  -1.794
# pheno_social_isolation                           -0.02982    0.03258  -0.915
# pheno_age_at_visit                               -0.28585    0.03292  -8.684
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.59262    0.03840  15.431
# pheno_msex1                                       0.32018    0.09338   3.429
#                                                  Pr(>|t|)
# (Intercept)                                      0.073479 .
# pheno_social_isolation                           0.360467
# pheno_age_at_visit                                < 2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                      0.000657 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7151 on 494 degrees of freedom
# Multiple R-squared:  0.4927,	Adjusted R-squared:  0.4886
# F-statistic:   120 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0001675449
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Med_Orb_L_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3465 -0.5837 -0.0591  0.5202  4.5374
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.06171    0.04368  -1.413
# pheno_social_isolation                            0.01086    0.03789   0.287
# pheno_age_at_visit                               -0.25965    0.03828  -6.783
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.44981    0.04466  10.071
# pheno_msex1                                       0.29327    0.10859   2.701
#                                                  Pr(>|t|)
# (Intercept)                                       0.15837
# pheno_social_isolation                            0.77450
# pheno_age_at_visit                               3.37e-11 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                       0.00716 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8316 on 494 degrees of freedom
# Multiple R-squared:  0.3139,	Adjusted R-squared:  0.3084
# F-statistic: 56.51 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001282392
#
# Formula (Full Model): regionsurfacestats_AAL_lh_Frontal_Med_Orb_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4278 -0.6240 -0.1005  0.5318  3.7155
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.02008    0.04946  -0.406
# pheno_social_isolation                            0.05195    0.04290   1.211
# pheno_age_at_visit                               -0.02031    0.04334  -0.469
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.31880    0.05057   6.304
# pheno_msex1                                       0.09545    0.12296   0.776
#                                                  Pr(>|t|)
# (Intercept)                                         0.685
# pheno_social_isolation                              0.226
# pheno_age_at_visit                                  0.640
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV 6.44e-10 ***
# pheno_msex1                                         0.438
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9417 on 494 degrees of freedom
# Multiple R-squared:  0.1204,	Adjusted R-squared:  0.1133
# F-statistic: 16.91 on 4 and 494 DF,  p-value: 5.307e-13
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0008356905
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Sup_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6685 -0.4920 -0.0413  0.4005  2.6410
#
# Coefficients:
#                                                    Estimate Std. Error t value
# (Intercept)                                      -0.0532144  0.0380729  -1.398
# pheno_social_isolation                            0.0001977  0.0330238   0.006
# pheno_age_at_visit                               -0.2928940  0.0333638  -8.779
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.5988999  0.0389273  15.385
# pheno_msex1                                       0.2528949  0.0946474   2.672
#                                                  Pr(>|t|)
# (Intercept)                                       0.16283
# pheno_social_isolation                            0.99523
# pheno_age_at_visit                                < 2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                       0.00779 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7248 on 494 degrees of freedom
# Multiple R-squared:  0.4788,	Adjusted R-squared:  0.4746
# F-statistic: 113.5 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.00106138
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Sup_Orb_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4669 -0.5054 -0.0349  0.5391  4.0946
#
# Coefficients:
#                                                   Estimate Std. Error t value
# (Intercept)                                      -0.043401   0.043569  -0.996
# pheno_social_isolation                           -0.001188   0.037791  -0.031
# pheno_age_at_visit                               -0.340105   0.038180  -8.908
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.437139   0.044546   9.813
# pheno_msex1                                       0.206257   0.108309   1.904
#                                                  Pr(>|t|)
# (Intercept)                                        0.3197
# pheno_social_isolation                             0.9749
# pheno_age_at_visit                                 <2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV   <2e-16 ***
# pheno_msex1                                        0.0574 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8295 on 494 degrees of freedom
# Multiple R-squared:  0.3175,	Adjusted R-squared:  0.312
# F-statistic: 57.45 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.00138858
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Mid_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8148 -0.4826 -0.0670  0.3939  3.6093
#
# Coefficients:
#                                                   Estimate Std. Error t value
# (Intercept)                                      -0.044703   0.040844  -1.094
# pheno_social_isolation                           -0.006143   0.035427  -0.173
# pheno_age_at_visit                               -0.264578   0.035792  -7.392
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.553935   0.041761  13.265
# pheno_msex1                                       0.212445   0.101536   2.092
#                                                  Pr(>|t|)
# (Intercept)                                        0.2743
# pheno_social_isolation                             0.8624
# pheno_age_at_visit                               6.23e-13 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                        0.0369 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7776 on 494 degrees of freedom
# Multiple R-squared:  0.4002,	Adjusted R-squared:  0.3953
# F-statistic:  82.4 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001184823
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Mid_Orb_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.6553 -0.5750 -0.0390  0.5694  2.6476
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.01686    0.04377  -0.385
# pheno_social_isolation                           -0.03949    0.03797  -1.040
# pheno_age_at_visit                               -0.34455    0.03836  -8.982
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.45927    0.04476  10.262
# pheno_msex1                                       0.08011    0.10882   0.736
#                                                  Pr(>|t|)
# (Intercept)                                         0.700
# pheno_social_isolation                              0.299
# pheno_age_at_visit                                 <2e-16 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV   <2e-16 ***
# pheno_msex1                                         0.462
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8334 on 494 degrees of freedom
# Multiple R-squared:  0.3111,	Adjusted R-squared:  0.3055
# F-statistic: 55.76 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0001149032
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Inf_Oper_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4533 -0.5161 -0.0547  0.4486  3.9709
#
# Coefficients:
#                                                   Estimate Std. Error t value
# (Intercept)                                      -0.036521   0.043162  -0.846
# pheno_social_isolation                           -0.006891   0.037438  -0.184
# pheno_age_at_visit                               -0.202092   0.037823  -5.343
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.520198   0.044131  11.788
# pheno_msex1                                       0.173561   0.107299   1.618
#                                                  Pr(>|t|)
# (Intercept)                                         0.398
# pheno_social_isolation                              0.854
# pheno_age_at_visit                                1.4e-07 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                         0.106
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8217 on 494 degrees of freedom
# Multiple R-squared:  0.3302,	Adjusted R-squared:  0.3248
# F-statistic: 60.88 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001317914
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Inf_Tri_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1190 -0.5244 -0.0956  0.4199  3.9315
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.10104    0.04441  -2.275
# pheno_social_isolation                            0.01506    0.03852   0.391
# pheno_age_at_visit                               -0.25280    0.03892  -6.496
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.36460    0.04541   8.030
# pheno_msex1                                       0.48016    0.11040   4.349
#                                                  Pr(>|t|)
# (Intercept)                                        0.0233 *
# pheno_social_isolation                             0.6961
# pheno_age_at_visit                               2.02e-10 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV 7.21e-15 ***
# pheno_msex1                                      1.66e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8455 on 494 degrees of freedom
# Multiple R-squared:  0.2909,	Adjusted R-squared:  0.2851
# F-statistic: 50.66 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001223574
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Inf_Orb_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8854 -0.4481 -0.0391  0.4283 13.6426
#
# Coefficients:
#                                                  Estimate Std. Error t value
# (Intercept)                                      -0.07418    0.04616  -1.607
# pheno_social_isolation                            0.02124    0.04004   0.531
# pheno_age_at_visit                               -0.22463    0.04045  -5.553
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.35535    0.04720   7.529
# pheno_msex1                                       0.35254    0.11475   3.072
#                                                  Pr(>|t|)
# (Intercept)                                       0.10868
# pheno_social_isolation                            0.59592
# pheno_age_at_visit                               4.59e-08 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV 2.44e-13 ***
# pheno_msex1                                       0.00224 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8788 on 494 degrees of freedom
# Multiple R-squared:  0.2339,	Adjusted R-squared:  0.2277
# F-statistic: 37.71 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001120911
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Sup_Medial_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3150 -0.4617 -0.0690  0.4177  4.0264
#
# Coefficients:
#                                                   Estimate Std. Error t value
# (Intercept)                                      -0.085367   0.038462  -2.220
# pheno_social_isolation                            0.005513   0.033361   0.165
# pheno_age_at_visit                               -0.229477   0.033705  -6.808
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.564514   0.039325  14.355
# pheno_msex1                                       0.405695   0.095614   4.243
#                                                  Pr(>|t|)
# (Intercept)                                        0.0269 *
# pheno_social_isolation                             0.8688
# pheno_age_at_visit                               2.87e-11 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                      2.63e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7323 on 494 degrees of freedom
# Multiple R-squared:  0.4681,	Adjusted R-squared:  0.4638
# F-statistic: 108.7 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001053633
#
# Formula (Full Model): regionsurfacestats_AAL_rh_Frontal_Med_Orb_R_SurfArea ~ pheno_social_isolation + pheno_age_at_visit + brainmeasures_EstimatedTotalIntraCranialVol_eTIV + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.25885 -0.51526 -0.05742  0.54966  3.08532
#
# Coefficients:
#                                                    Estimate Std. Error t value
# (Intercept)                                      -0.0658241  0.0415360  -1.585
# pheno_social_isolation                            0.0002584  0.0360277   0.007
# pheno_age_at_visit                               -0.2469095  0.0363986  -6.783
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  0.5125198  0.0424681  12.068
# pheno_msex1                                       0.3128211  0.1032565   3.030
#                                                  Pr(>|t|)
# (Intercept)                                       0.11366
# pheno_social_isolation                            0.99428
# pheno_age_at_visit                               3.36e-11 ***
# brainmeasures_EstimatedTotalIntraCranialVol_eTIV  < 2e-16 ***
# pheno_msex1                                       0.00258 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7908 on 494 degrees of freedom
# Multiple R-squared:  0.3797,	Adjusted R-squared:  0.3747
# F-statistic: 75.59 on 4 and 494 DF,  p-value: < 2.2e-16
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001263228

# %%
# Run a model
data_model <- anat_data
#main_dependent <- "pheno_social_isolation"
#main_predictor <- "bold_AAL_Precuneus_L_alff"
#covariates_numeric <- c("pheno_age_at_visit",'bold_wholebrain_average_alff')
#covariates_factor <- c("pheno_msex")
# Find all columns with "bold_AAL_XXXXX_t1t2ratio"
string_to_match <- "bold.*Frontal.*t1t2ratio"
columns_match <- names(data_model)[grep(string_to_match, colnames(data_model))]
for (main_dependent in columns_match) {
    main_predictor <- "pheno_social_isolation"
    covariates_numeric <- c("pheno_age_at_visit")
    covariates_factor <- c("pheno_msex")
    model <- run_ols_model(dataframe=data_model,
                  main_dependent = main_dependent,
                  main_predictor = main_predictor,
                  covariates_numeric = covariates_numeric,
                  covariates_factor = covariates_factor)
    }
# Out:
# Formula (Full Model): bold_AAL_Frontal_Sup_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.1691 -0.0844 -0.0513 -0.0194 22.0636
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.012303   0.050889   0.242    0.809
# pheno_social_isolation -0.009493   0.046080  -0.206    0.837
# pheno_age_at_visit      0.041877   0.046017   0.910    0.363
# pheno_msex1            -0.057767   0.110475  -0.523    0.601
#
# Residual standard error: 1.002 on 489 degrees of freedom
# Multiple R-squared:  0.002332,	Adjusted R-squared:  -0.003789
# F-statistic: 0.3809 on 3 and 489 DF,  p-value: 0.7668
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001961612
#
# Formula (Full Model): bold_AAL_Frontal_Sup_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.8576  -0.0286   0.0066   0.0944   1.1184
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.044387   0.050643   0.876   0.3812
# pheno_social_isolation -0.061603   0.045857  -1.343   0.1798
# pheno_age_at_visit     -0.009217   0.045795  -0.201   0.8406
# pheno_msex1            -0.208406   0.109941  -1.896   0.0586 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.997 on 489 degrees of freedom
# Multiple R-squared:  0.01196,	Adjusted R-squared:  0.005897
# F-statistic: 1.973 on 3 and 489 DF,  p-value: 0.1171
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.001632445
#
# Formula (Full Model): bold_AAL_Frontal_Sup_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.4738 -0.1590 -0.0413  0.0549 21.7292
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.012052   0.050882   0.237    0.813
# pheno_social_isolation  0.000521   0.046074   0.011    0.991
# pheno_age_at_visit     -0.046100   0.046011  -1.002    0.317
# pheno_msex1            -0.056587   0.110460  -0.512    0.609
#
# Residual standard error: 1.002 on 489 degrees of freedom
# Multiple R-squared:  0.002599,	Adjusted R-squared:  -0.00352
# F-statistic: 0.4247 on 3 and 489 DF,  p-value: 0.7354
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.002047739
#
# Formula (Full Model): bold_AAL_Frontal_Sup_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.4526 -0.5294  0.0490  0.5422  6.9638
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.01154    0.04927   0.234    0.815
# pheno_social_isolation  0.01456    0.04462   0.326    0.744
# pheno_age_at_visit     -0.25634    0.04456  -5.753 1.55e-08 ***
# pheno_msex1            -0.05420    0.10697  -0.507    0.613
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9701 on 489 degrees of freedom
# Multiple R-squared:  0.06469,	Adjusted R-squared:  0.05895
# F-statistic: 11.27 on 3 and 489 DF,  p-value: 3.662e-07
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001716088
#
# Formula (Full Model): bold_AAL_Frontal_Mid_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.2876 -0.0783 -0.0484 -0.0084 22.0750
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.013738   0.050852   0.270    0.787
# pheno_social_isolation  0.054853   0.046047   1.191    0.234
# pheno_age_at_visit      0.007801   0.045984   0.170    0.865
# pheno_msex1            -0.064504   0.110395  -0.584    0.559
#
# Residual standard error: 1.001 on 489 degrees of freedom
# Multiple R-squared:  0.003771,	Adjusted R-squared:  -0.00234
# F-statistic: 0.6171 on 3 and 489 DF,  p-value: 0.6042
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0008572424
#
# Formula (Full Model): bold_AAL_Frontal_Mid_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -11.3196  -0.3697   0.0461   0.3607  11.7808
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.01460    0.05037  -0.290  0.77213
# pheno_social_isolation  0.02660    0.04561   0.583  0.56002
# pheno_age_at_visit     -0.14916    0.04555  -3.275  0.00113 **
# pheno_msex1             0.06853    0.10935   0.627  0.53116
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9917 on 489 degrees of freedom
# Multiple R-squared:  0.02256,	Adjusted R-squared:  0.01656
# F-statistic: 3.762 on 3 and 489 DF,  p-value: 0.01085
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.00132436
#
# Formula (Full Model): bold_AAL_Frontal_Mid_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -12.9968  -0.4211   0.0355   0.4188   5.6282
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.036326   0.049351   0.736    0.462
# pheno_social_isolation  0.007719   0.044687   0.173    0.863
# pheno_age_at_visit     -0.241703   0.044626  -5.416 9.57e-08 ***
# pheno_msex1            -0.170557   0.107135  -1.592    0.112
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9716 on 489 degrees of freedom
# Multiple R-squared:  0.06174,	Adjusted R-squared:  0.05599
# F-statistic: 10.73 on 3 and 489 DF,  p-value: 7.728e-07
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.00186907
#
# Formula (Full Model): bold_AAL_Frontal_Mid_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.5785 -0.2341 -0.0326  0.1537 19.5944
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.02902    0.05052   0.574  0.56600
# pheno_social_isolation  0.04442    0.04575   0.971  0.33204
# pheno_age_at_visit     -0.11928    0.04568  -2.611  0.00931 **
# pheno_msex1            -0.13624    0.10968  -1.242  0.21476
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9947 on 489 degrees of freedom
# Multiple R-squared:  0.0167,	Adjusted R-squared:  0.01067
# F-statistic: 2.769 on 3 and 489 DF,  p-value: 0.04121
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0001155211
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Oper_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8096 -0.1654 -0.0330  0.0716 21.5982
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.006963   0.050847   0.137    0.891
# pheno_social_isolation -0.025613   0.046041  -0.556    0.578
# pheno_age_at_visit     -0.051627   0.045979  -1.123    0.262
# pheno_msex1            -0.032692   0.110383  -0.296    0.767
#
# Residual standard error: 1.001 on 489 degrees of freedom
# Multiple R-squared:  0.004002,	Adjusted R-squared:  -0.002109
# F-statistic: 0.6549 on 3 and 489 DF,  p-value: 0.5802
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001412196
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Oper_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.2342  -0.3708   0.0194   0.3736   5.5165
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.007751   0.050174   0.154 0.877297
# pheno_social_isolation -0.005755   0.045433  -0.127 0.899248
# pheno_age_at_visit     -0.172224   0.045371  -3.796 0.000166 ***
# pheno_msex1            -0.036392   0.108923  -0.334 0.738444
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9878 on 489 degrees of freedom
# Multiple R-squared:  0.03017,	Adjusted R-squared:  0.02422
# F-statistic:  5.07 on 3 and 489 DF,  p-value: 0.001821
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001959435
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Tri_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.9635  -0.2938   0.0463   0.2794   6.6954
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.01494    0.05048   0.296   0.7674
# pheno_social_isolation -0.04312    0.04571  -0.943   0.3460
# pheno_age_at_visit     -0.11715    0.04565  -2.566   0.0106 *
# pheno_msex1            -0.07013    0.10959  -0.640   0.5225
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9939 on 489 degrees of freedom
# Multiple R-squared:  0.01828,	Adjusted R-squared:  0.01225
# F-statistic: 3.034 on 3 and 489 DF,  p-value: 0.02891
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.000222349
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Tri_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -20.6776  -0.0651   0.0300   0.1156   6.3397
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.006003   0.050828  -0.118    0.906
# pheno_social_isolation -0.026040   0.046024  -0.566    0.572
# pheno_age_at_visit     -0.057971   0.045962  -1.261    0.208
# pheno_msex1             0.028186   0.110342   0.255    0.798
#
# Residual standard error: 1.001 on 489 degrees of freedom
# Multiple R-squared:  0.004738,	Adjusted R-squared:  -0.001368
# F-statistic: 0.776 on 3 and 489 DF,  p-value: 0.5078
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001389397
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -22.0756   0.0066   0.0465   0.0821   0.6348
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.01232    0.05088  -0.242    0.809
# pheno_social_isolation  0.03817    0.04608   0.828    0.408
# pheno_age_at_visit     -0.02718    0.04601  -0.591    0.555
# pheno_msex1             0.05783    0.11047   0.524    0.601
#
# Residual standard error: 1.002 on 489 degrees of freedom
# Multiple R-squared:  0.002506,	Adjusted R-squared:  -0.003613
# F-statistic: 0.4095 on 3 and 489 DF,  p-value: 0.7462
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.0006423245
#
# Formula (Full Model): bold_AAL_Frontal_Inf_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.0501 -0.6492  0.0355  0.6565  3.5607
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)             0.01499    0.04839   0.310    0.757
# pheno_social_isolation  0.01122    0.04382   0.256    0.798
# pheno_age_at_visit     -0.31401    0.04376  -7.175 2.69e-12 ***
# pheno_msex1            -0.07039    0.10506  -0.670    0.503
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9528 on 489 degrees of freedom
# Multiple R-squared:  0.09774,	Adjusted R-squared:  0.0922
# F-statistic: 17.66 on 3 and 489 DF,  p-value: 6.748e-11
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.001731103
#
# Formula (Full Model): bold_AAL_Frontal_Sup_Medial_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -22.0242   0.0070   0.0447   0.0746   1.5468
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.012442   0.050863  -0.245    0.807
# pheno_social_isolation -0.053220   0.046057  -1.156    0.248
# pheno_age_at_visit     -0.003444   0.045994  -0.075    0.940
# pheno_msex1             0.058420   0.110419   0.529    0.597
#
# Residual standard error: 1.001 on 489 degrees of freedom
# Multiple R-squared:  0.003343,	Adjusted R-squared:  -0.002772
# F-statistic: 0.5467 on 3 and 489 DF,  p-value: 0.6506
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0006860924
#
# Formula (Full Model): bold_AAL_Frontal_Sup_Medial_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -22.0614   0.0084   0.0462   0.0756   0.9372
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.013334   0.050858  -0.262    0.793
# pheno_social_isolation -0.053938   0.046052  -1.171    0.242
# pheno_age_at_visit     -0.005276   0.045989  -0.115    0.909
# pheno_msex1             0.062608   0.110408   0.567    0.571
#
# Residual standard error: 1.001 on 489 degrees of freedom
# Multiple R-squared:  0.003549,	Adjusted R-squared:  -0.002565
# F-statistic: 0.5805 on 3 and 489 DF,  p-value: 0.628
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.0007607708
#
# Formula (Full Model): bold_AAL_Frontal_Med_Orb_L_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.8584 -0.3066 -0.0677  0.1382 19.3534
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -1.544e-02  5.092e-02  -0.303    0.762
# pheno_social_isolation  3.953e-06  4.611e-02   0.000    1.000
# pheno_age_at_visit     -1.431e-02  4.605e-02  -0.311    0.756
# pheno_msex1             7.250e-02  1.105e-01   0.656    0.512
#
# Residual standard error: 1.003 on 489 degrees of freedom
# Multiple R-squared:  0.001109,	Adjusted R-squared:  -0.005019
# F-statistic: 0.181 on 3 and 489 DF,  p-value: 0.9093
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): -0.002051059
#
# Formula (Full Model): bold_AAL_Frontal_Med_Orb_R_t1t2ratio ~ pheno_social_isolation + pheno_age_at_visit + pheno_msex
#
# Model Summary (Full Model):
#
# Call:
# lm(formula = formula_string_full, data = data_subset)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5306 -0.2223 -0.0397  0.1422 20.6457
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.02979    0.04991  -0.597 0.550873
# pheno_social_isolation  0.12296    0.04519   2.721 0.006744 **
# pheno_age_at_visit     -0.16852    0.04513  -3.734 0.000211 ***
# pheno_msex1             0.13987    0.10835   1.291 0.197345
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9826 on 489 degrees of freedom
# Multiple R-squared:  0.04034,	Adjusted R-squared:  0.03445
# F-statistic: 6.851 on 3 and 489 DF,  p-value: 0.0001577
#
#
# Change in Adjusted R-squared (Full vs Reduced Model): 0.01261676
